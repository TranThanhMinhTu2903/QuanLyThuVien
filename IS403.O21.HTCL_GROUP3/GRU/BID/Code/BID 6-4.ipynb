# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Input
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error

# %%
# Load and preprocess the data
df = pd.read_csv("C:/Users/trant/OneDrive/Tài liệu/Đồ án Phân tích dữ liệu/DATASET/BID.VN-1.csv")

# %%
# Convert the time column to datetime
df['Date'] = pd.to_datetime(df['Date'])
# Select column 'Close' as the dependent variable
df_Close = df[['Date', 'Close']]
# Reset the index of the DataFrame
df_Close = df_Close.reset_index(drop=True)

# %%
# Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df_Close['Close'] = scaler.fit_transform(np.array(df_Close['Close']).reshape(-1, 1))

# Split train, test set
train_size = int(0.6 * len(df_Close))
test_size = len(df_Close) - train_size

train_data = df_Close[:train_size]
test_data = df_Close[train_size:]

# %%
# Function to create dataset
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)
# Reshape data

time_step = 100
X_train, y_train = create_dataset(train_data[['Close']].values, time_step)
X_test, y_test = create_dataset(test_data[['Close']].values, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Define GRU model
model = Sequential()
model.add(Input(shape=(time_step, 1)))
model.add(GRU(64))
model.add(Dense(1))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0589 - val_loss: 0.0375
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0096 - val_loss: 0.0294
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0050 - val_loss: 0.0481
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0047 - val_loss: 0.0146
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0029 - val_loss: 0.0120
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0021 - val_loss: 0.0072
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.3717e-04 - val_loss: 9.5519e-04
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.7410e-04 - val_loss: 9.4693e-04
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.1108e-04 - val_loss: 9.6169e-04
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.9182e-04 - val_loss: 9.0619e-04
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.4507e-04 - val_loss: 9.6917e-04
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.2290e-04 - val_loss: 9.3218e-04
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.5686e-04 - val_loss: 8.4401e-04
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.3340e-04 - val_loss: 9.7337e-04
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.0477e-04 - val_loss: 8.8835e-04
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.3710e-04 - val_loss: 8.3031e-04
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.3402e-04 - val_loss: 8.5793e-04
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.1643e-04 - val_loss: 9.1196e-04
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.3052e-04 - val_loss: 8.2588e-04
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 6.8988e-04 - val_loss: 8.5042e-04
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.6153e-04 - val_loss: 7.6662e-04
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 6.5553e-04 - val_loss: 9.9398e-04
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.9330e-04 - val_loss: 7.5532e-04
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.6706e-04 - val_loss: 7.4527e-04
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.5968e-04 - val_loss: 8.1407e-04
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.2702e-04 - val_loss: 0.0012
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7.0068e-04 - val_loss: 7.4032e-04
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.0524e-04 - val_loss: 7.2061e-04
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 7.0886e-04 - val_loss: 0.0010
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.5186e-04 - val_loss: 7.1225e-04
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.9274e-04 - val_loss: 7.0775e-04
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.0029e-04 - val_loss: 7.4153e-04
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.6355e-04 - val_loss: 7.7363e-04
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.3239e-04 - val_loss: 7.2194e-04
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.8491e-04 - val_loss: 9.1725e-04
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 6.1605e-04 - val_loss: 7.4657e-04
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.6235e-04 - val_loss: 7.0899e-04
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.2769e-04 - val_loss: 0.0010
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.2520e-04 - val_loss: 7.0007e-04
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.1424e-04 - val_loss: 7.3553e-04
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.7210e-04 - val_loss: 8.4260e-04
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.9353e-04 - val_loss: 6.8216e-04
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.3047e-04 - val_loss: 7.5908e-04
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.0829e-04 - val_loss: 6.7455e-04
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.2895e-04 - val_loss: 8.1285e-04
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.7789e-04 - val_loss: 6.9365e-04
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.2723e-04 - val_loss: 8.6654e-04
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.0587e-04 - val_loss: 0.0010
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.9050e-04 - val_loss: 7.4365e-04
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.3241e-04 - val_loss: 6.9271e-04
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.3783e-04 - val_loss: 7.7273e-04
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 5.6002e-04 - val_loss: 7.9376e-04
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.6224e-04 - val_loss: 6.6029e-04
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.7681e-04 - val_loss: 7.4427e-04
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.9603e-04 - val_loss: 8.7654e-04
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.2014e-04 - val_loss: 8.6952e-04
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.4871e-04 - val_loss: 7.4718e-04
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.3527e-04 - val_loss: 7.0008e-04
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.5307e-04 - val_loss: 6.6172e-04
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.9917e-04 - val_loss: 6.7222e-04
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.0525e-04 - val_loss: 7.9650e-04
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.2781e-04 - val_loss: 7.4542e-04
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.7725e-04 - val_loss: 8.6308e-04
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.3009e-04 - val_loss: 7.9636e-04
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.8905e-04 - val_loss: 7.6899e-04
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.2037e-04 - val_loss: 6.6880e-04
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.7416e-04 - val_loss: 6.3731e-04
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.8997e-04 - val_loss: 6.6342e-04
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.4031e-04 - val_loss: 8.1880e-04
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.5841e-04 - val_loss: 8.2942e-04
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.9655e-04 - val_loss: 6.8481e-04
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.9531e-04 - val_loss: 6.4423e-04
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.3098e-04 - val_loss: 0.0011
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.2211e-04 - val_loss: 7.7942e-04
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.6564e-04 - val_loss: 7.7346e-04
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.0249e-04 - val_loss: 7.2884e-04
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.9788e-04 - val_loss: 6.4857e-04
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.8433e-04 - val_loss: 7.2972e-04
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.5542e-04 - val_loss: 6.4049e-04
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.1839e-04 - val_loss: 6.6266e-04
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.3789e-04 - val_loss: 9.1129e-04
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.2209e-04 - val_loss: 8.0039e-04
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.5529e-04 - val_loss: 6.6123e-04
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.4445e-04 - val_loss: 6.1884e-04
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.7547e-04 - val_loss: 6.2091e-04
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.4362e-04 - val_loss: 7.9694e-04
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.4099e-04 - val_loss: 6.9275e-04
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.3305e-04 - val_loss: 6.8084e-04
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.3285e-04 - val_loss: 0.0011
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.5405e-04 - val_loss: 7.4789e-04
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.5398e-04 - val_loss: 6.1422e-04
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.3340e-04 - val_loss: 6.0767e-04
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.0444e-04 - val_loss: 6.1931e-04
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 4.0367e-04 - val_loss: 7.6981e-04
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 4.6098e-04 - val_loss: 7.5730e-04
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 4.4029e-04 - val_loss: 7.6397e-04
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.1850e-04 - val_loss: 6.2755e-04
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.2184e-04 - val_loss: 6.1991e-04

# %%
# Dự đoán dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)

# Chuẩn hóa dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# Make predictions on the test set
y_pred_test = model.predict(X_test)

# Reshape test data and inverse transform if necessary
y_test = y_test.reshape(-1, 1)
y_test_inv = scaler.inverse_transform(y_test)

# Assuming y_pred_test is already in the shape required for inverse transform
y_pred_test = y_pred_test.reshape(-1, 1)
y_pred_test_inv = scaler.inverse_transform(y_pred_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# Calculate MAPE for test set
test_MAPE = mean_absolute_percentage_error(y_test_inv, y_pred_test_inv)

# Calculate RMSE for test set
test_RMSE = mean_squared_error(y_test_inv, y_pred_test_inv, squared=False)

# Calculate MSLE for test set
test_MSLE = mean_squared_log_error(y_test_inv, y_pred_test_inv)

print('Test MAPE:', test_MAPE)
print('Test RMSE:', test_RMSE)
print('Test MSLE:', test_MSLE)
# Out:
# Test MAPE: 0.014588659819971976
# Test RMSE: 816.8971765475386
# Test MSLE: 0.0004481978202731614

# %%
# Hàm dự đoán trong khoảng thời gian nhất định
def predict_future_days(model, data, days, time_step):
    temp_input = list(data[-time_step:])
    lst_output = []

    for _ in range(days):
        x_input = np.array(temp_input[-time_step:])
        x_input = x_input.reshape(1, time_step, 1)
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())

    return lst_output

# Dự đoán 30, 60, 90 ngày tiếp theo
future_30_days = predict_future_days(model, test_data['Close'].values, 30, time_step)
future_60_days = predict_future_days(model, test_data['Close'].values, 60, time_step)
future_90_days = predict_future_days(model, test_data['Close'].values, 90, time_step)

# Tạo dải ngày dự đoán mới
last_index_date = df_Close['Date'].iloc[-1]
predict_dates_30 = pd.date_range(start=last_index_date + pd.Timedelta(days=1), periods=30)
predict_dates_60 = pd.date_range(start=last_index_date + pd.Timedelta(days=1), periods=60)
predict_dates_90 = pd.date_range(start=last_index_date + pd.Timedelta(days=1), periods=90)

# %%
plt.figure(figsize=(12, 5))

plt.plot(df_Close['Date'][:train_size], scaler.inverse_transform(train_data[['Close']]))
plt.plot(df_Close['Date'][train_size:], scaler.inverse_transform(test_data[['Close']]))
plt.plot(df_Close['Date'][train_size + time_step:train_size + time_step + len(y_pred)], y_pred)
plt.plot(predict_dates_30, scaler.inverse_transform(future_30_days[:30]), linestyle='dashed')
plt.plot(predict_dates_60, scaler.inverse_transform(future_60_days[:60]), linestyle='dashed')
plt.plot(predict_dates_90, scaler.inverse_transform(future_90_days[:90]), linestyle='dashed')

plt.title("BIDV's Stock Price Data With GRU Predictions")
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend(['Train', 'Test', 'Predict', 'Predict30days', 'Predict60days', 'Predict90days'])
plt.grid(True)
plt.show()
